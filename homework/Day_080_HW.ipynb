# %% [markdown]
# # 請結合前面的知識與程式碼，比較不同的 optimizer 與 learning rate 組合對訓練的結果與影響
# ### 常見的 optimizer 包含
# * SGD
# * RMSprop
# * AdaGrad
# * Adam

# %%
import os
import keras
import tensorflow as tf
# Disable GPU
# 本作業可以不需使用 GPU, 將 GPU 設定為 "無" (若想使用可自行開啟)
# 使用第一張 GPU 卡
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
# 自動增長 GPU 記憶體用量
gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.75) #占用75%顯存
sess =  tf.compat.v1.Session(config=tf.compat.v1.ConfigProto(gpu_options=gpu_options))

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    # 資料前處理 - 標準化
    x = x / 255.
    if flatten:
         # 將資料從圖形 (RGB) 轉為向量 (Single Vector)
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        # 用np_utils裡的to_categorical來做one-hot encoding的轉換：
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
# 資料前處理 - X 標準化
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
# 資料前處理 -Y 轉成 onehot
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128, 64]):
    """
    Build your own model
    """
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, activation="relu", name="hidden_layer"+str(i+1))(input_layer)
            #Dense是全連接層，該層的輸出維度n_units，激活函數='relu'
        else:
            x = keras.layers.Dense(units=n_units, activation="relu", name="hidden_layer"+str(i+1))(x)
            #Dense是全連接層，該層的輸出維度n_units，激活函數='relu'
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
           #Dense是全連接層，該層的輸出維度n_units，激活函數='softmax'
    
    #定義一個具有輸入和輸出的模型
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
## 超參數設定
"""
Set your required experiment parameters
"""
LEARNING_RATE = [0.001, 0.01, 0.1, 1] #學習率
EPOCHS = 50 #訓練50週期，訓練集所有樣本（數據、記錄）參與訓練一次爲一個週期
BATCH_SIZE = 256 #訓練時每個批次的樣本數。訓練樣本數/批次樣本數 = 批次數（每個週期）
OPT = [keras.optimizers.SGD, keras.optimizers.RMSprop, keras.optimizers.Adagrad, keras.optimizers.Adam] #優化器

# %%
results = {}
"""
建立你的訓練與實驗迴圈並蒐集資料
"""
"""
使用迴圈，建立不同 Learning rate 的模型並訓練
"""
for lr in LEARNING_RATE:
    for optimizers in OPT:
        keras.backend.clear_session() # 把舊的 Graph 清掉
        print("Experiment with LR = {}, OPT={}" .format(lr,OPT))
        model = build_mlp(input_shape=x_train.shape[1:])
        # 用 Keras 內建方法檢視模型各層參數量
        model.summary()
        #優化器參數設定
        model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizers(lr=lr))
        '''
        參數說明:
        lr：float> = 0.學習率。
        '''
    
    model.fit(x_train, y_train, #訓練資料
              epochs=EPOCHS,   #訓練EPOCHS週期，訓練集所有樣本（數據、記錄）參與訓練一次爲一個週期
              batch_size=BATCH_SIZE,  #訓練時每個批次的樣本數。訓練樣本數/批次樣本數 = 批次數（每個週期）
              validation_data=(x_test, y_test),  #驗證資料
              shuffle=True) #每次epochs後，將訓練集打亂順序
    
    # Collect results
    #ㄘhistory.history:記錄了損失函數和其他指標的數值隨epoch變化的情況，如果有驗證集的話，也包含了驗證集的這些指標變化情況
    train_loss = model.history.history["loss"]
    valid_loss = model.history.history["val_loss"]
    train_acc = model.history.history["accuracy"]
    valid_acc = model.history.history["val_accuracy"]
    
    exp_name_tag = "Experiment with LR = {}, OPT={}" .format(lr,OPT)
    results[exp_name_tag] = {'train-loss': train_loss,
                             'valid-loss': valid_loss,
                             'train-accuracy': train_acc,
                             'valid-accuracy': valid_acc}
# Out:
# Experiment with LR = 0.001, OPT=[<class 'keras.optimizers.SGD'>, <class 'keras.optimizers.RMSprop'>, <class 'keras.optimizers.Adagrad'>, <class 'keras.optimizers.Adam'>]
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# hidden_layer4 (Dense)        (None, 64)                8256
# _________________________________________________________________
# output (Dense)               (None, 10)                650
# =================================================================
# Total params: 1,746,506
# Trainable params: 1,746,506
# Non-trainable params: 0
# _________________________________________________________________
# Experiment with LR = 0.001, OPT=[<class 'keras.optimizers.SGD'>, <class 'keras.optimizers.RMSprop'>, <class 'keras.optimizers.Adagrad'>, <class 'keras.optimizers.Adam'>]
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# hidden_layer4 (Dense)        (None, 64)                8256
# _________________________________________________________________
# output (Dense)               (None, 10)                650
# =================================================================
# Total params: 1,746,506
# Trainable params: 1,746,506
# Non-trainable params: 0
# _________________________________________________________________
# Experiment with LR = 0.001, OPT=[<class 'keras.optimizers.SGD'>, <class 'keras.optimizers.RMSprop'>, <class 'keras.optimizers.Adagrad'>, <class 'keras.optimizers.Adam'>]
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# hidden_layer4 (Dense)        (None, 64)                8256
# _________________________________________________________________
# output (Dense)               (None, 10)                650
# =================================================================
# Total params: 1,746,506
# Trainable params: 1,746,506
# Non-trainable params: 0
# _________________________________________________________________
# Experiment with LR = 0.001, OPT=[<class 'keras.optimizers.SGD'>, <class 'keras.optimizers.RMSprop'>, <class 'keras.optimizers.Adagrad'>, <class 'keras.optimizers.Adam'>]
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# hidden_layer4 (Dense)        (None, 64)                8256
# _________________________________________________________________
# output (Dense)               (None, 10)                650
# =================================================================
# Total params: 1,746,506
# Trainable params: 1,746,506
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 3s 64us/step - loss: 1.9415 - accuracy: 0.2937 - val_loss: 1.8030 - val_accuracy: 0.3471
# Epoch 2/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 1.7199 - accuracy: 0.3835 - val_loss: 1.7129 - val_accuracy: 0.3928
# Epoch 3/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.6417 - accuracy: 0.4147 - val_loss: 1.6288 - val_accuracy: 0.4228
# Epoch 4/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.5696 - accuracy: 0.4392 - val_loss: 1.5538 - val_accuracy: 0.4477
# Epoch 5/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 1.5190 - accuracy: 0.4571 - val_loss: 1.5719 - val_accuracy: 0.4367
# Epoch 6/50
# 50000/50000 [==============================] - 3s 60us/step - loss: 1.4777 - accuracy: 0.4728 - val_loss: 1.5207 - val_accuracy: 0.4540
# Epoch 7/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 1.4428 - accuracy: 0.4849 - val_loss: 1.4704 - val_accuracy: 0.4724
# Epoch 8/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.4149 - accuracy: 0.4940 - val_loss: 1.4387 - val_accuracy: 0.4884
# Epoch 9/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.3942 - accuracy: 0.5016 - val_loss: 1.4358 - val_accuracy: 0.4850
# Epoch 10/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 1.3613 - accuracy: 0.5119 - val_loss: 1.4362 - val_accuracy: 0.4876
# Epoch 11/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.3360 - accuracy: 0.5258 - val_loss: 1.4246 - val_accuracy: 0.4858
# Epoch 12/50
# 50000/50000 [==============================] - 4s 84us/step - loss: 1.3092 - accuracy: 0.5330 - val_loss: 1.4020 - val_accuracy: 0.5046
# Epoch 13/50
# 50000/50000 [==============================] - 4s 87us/step - loss: 1.2928 - accuracy: 0.5384 - val_loss: 1.4018 - val_accuracy: 0.5001
# Epoch 14/50
# 50000/50000 [==============================] - 4s 82us/step - loss: 1.2670 - accuracy: 0.5480 - val_loss: 1.4243 - val_accuracy: 0.5049
# Epoch 15/50
# 50000/50000 [==============================] - 4s 77us/step - loss: 1.2517 - accuracy: 0.5509 - val_loss: 1.3826 - val_accuracy: 0.5113
# Epoch 16/50
# 50000/50000 [==============================] - 4s 73us/step - loss: 1.2263 - accuracy: 0.5599 - val_loss: 1.3601 - val_accuracy: 0.5191
# Epoch 17/50
# 50000/50000 [==============================] - 4s 71us/step - loss: 1.2065 - accuracy: 0.5667 - val_loss: 1.3599 - val_accuracy: 0.5217
# Epoch 18/50
# 50000/50000 [==============================] - 3s 64us/step - loss: 1.1853 - accuracy: 0.5764 - val_loss: 1.3840 - val_accuracy: 0.5141
# Epoch 19/50
# 50000/50000 [==============================] - 3s 61us/step - loss: 1.1589 - accuracy: 0.5840 - val_loss: 1.4049 - val_accuracy: 0.5139
# Epoch 20/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 1.1506 - accuracy: 0.5850 - val_loss: 1.3924 - val_accuracy: 0.5086
# Epoch 21/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 1.1181 - accuracy: 0.5985 - val_loss: 1.3861 - val_accuracy: 0.5115
# Epoch 22/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 1.1002 - accuracy: 0.6064 - val_loss: 1.3939 - val_accuracy: 0.5128
# Epoch 23/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.0938 - accuracy: 0.6079 - val_loss: 1.4064 - val_accuracy: 0.5161
# Epoch 24/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.0621 - accuracy: 0.6206 - val_loss: 1.3977 - val_accuracy: 0.5232
# Epoch 25/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.0466 - accuracy: 0.6231 - val_loss: 1.3984 - val_accuracy: 0.5137
# Epoch 26/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.0318 - accuracy: 0.6264 - val_loss: 1.4278 - val_accuracy: 0.5180
# Epoch 27/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.0086 - accuracy: 0.6393 - val_loss: 1.3931 - val_accuracy: 0.5308
# Epoch 28/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 1.0001 - accuracy: 0.6401 - val_loss: 1.4306 - val_accuracy: 0.5234
# Epoch 29/50
# 50000/50000 [==============================] - 3s 70us/step - loss: 0.9678 - accuracy: 0.6521 - val_loss: 1.4443 - val_accuracy: 0.5133
# Epoch 30/50
# 50000/50000 [==============================] - 3s 52us/step - loss: 0.9485 - accuracy: 0.6584 - val_loss: 1.4783 - val_accuracy: 0.5069
# Epoch 31/50
# 50000/50000 [==============================] - 3s 52us/step - loss: 0.9384 - accuracy: 0.6639 - val_loss: 1.4888 - val_accuracy: 0.5101
# Epoch 32/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 0.9143 - accuracy: 0.6698 - val_loss: 1.5047 - val_accuracy: 0.5126
# Epoch 33/50
# 50000/50000 [==============================] - 3s 53us/step - loss: 0.8986 - accuracy: 0.6793 - val_loss: 1.4811 - val_accuracy: 0.5244
# Epoch 34/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 0.8847 - accuracy: 0.6806 - val_loss: 1.5326 - val_accuracy: 0.5036
# Epoch 35/50
# 50000/50000 [==============================] - 3s 52us/step - loss: 0.8529 - accuracy: 0.6924 - val_loss: 1.5590 - val_accuracy: 0.5100
# Epoch 36/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 0.8567 - accuracy: 0.6896 - val_loss: 1.5333 - val_accuracy: 0.5162
# Epoch 37/50
# 50000/50000 [==============================] - 3s 52us/step - loss: 0.8378 - accuracy: 0.6958 - val_loss: 1.5577 - val_accuracy: 0.5165
# Epoch 38/50
# 50000/50000 [==============================] - 3s 52us/step - loss: 0.8083 - accuracy: 0.7102 - val_loss: 1.5539 - val_accuracy: 0.5219
# Epoch 39/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 0.8015 - accuracy: 0.7104 - val_loss: 1.5570 - val_accuracy: 0.5229
# Epoch 40/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 0.7814 - accuracy: 0.7180 - val_loss: 1.5899 - val_accuracy: 0.5147
# Epoch 41/50
# 50000/50000 [==============================] - 3s 53us/step - loss: 0.7571 - accuracy: 0.7271 - val_loss: 1.6590 - val_accuracy: 0.5146
# Epoch 42/50
# 50000/50000 [==============================] - 3s 53us/step - loss: 0.7518 - accuracy: 0.7298 - val_loss: 1.6701 - val_accuracy: 0.5202
# Epoch 43/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 0.7307 - accuracy: 0.7383 - val_loss: 1.7352 - val_accuracy: 0.5105
# Epoch 44/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 0.7151 - accuracy: 0.7431 - val_loss: 1.6964 - val_accuracy: 0.5142
# Epoch 45/50
# 50000/50000 [==============================] - 3s 52us/step - loss: 0.7109 - accuracy: 0.7454 - val_loss: 1.7430 - val_accuracy: 0.5124
# Epoch 46/50
# 50000/50000 [==============================] - 3s 52us/step - loss: 0.6801 - accuracy: 0.7549 - val_loss: 1.8313 - val_accuracy: 0.5109
# Epoch 47/50
# 50000/50000 [==============================] - 3s 52us/step - loss: 0.6816 - accuracy: 0.7540 - val_loss: 1.8721 - val_accuracy: 0.5067
# Epoch 48/50
# 50000/50000 [==============================] - 3s 52us/step - loss: 0.6786 - accuracy: 0.7557 - val_loss: 1.8003 - val_accuracy: 0.5167
# Epoch 49/50
# 50000/50000 [==============================] - 3s 53us/step - loss: 0.6308 - accuracy: 0.7741 - val_loss: 1.8694 - val_accuracy: 0.5123
# Epoch 50/50
# 50000/50000 [==============================] - 3s 53us/step - loss: 0.6320 - accuracy: 0.7745 - val_loss: 1.9188 - val_accuracy: 0.5013
# Experiment with LR = 0.01, OPT=[<class 'keras.optimizers.SGD'>, <class 'keras.optimizers.RMSprop'>, <class 'keras.optimizers.Adagrad'>, <class 'keras.optimizers.Adam'>]
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# hidden_layer4 (Dense)        (None, 64)                8256
# _________________________________________________________________
# output (Dense)               (None, 10)                650
# =================================================================
# Total params: 1,746,506
# Trainable params: 1,746,506
# Non-trainable params: 0
# _________________________________________________________________
# Experiment with LR = 0.01, OPT=[<class 'keras.optimizers.SGD'>, <class 'keras.optimizers.RMSprop'>, <class 'keras.optimizers.Adagrad'>, <class 'keras.optimizers.Adam'>]
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# hidden_layer4 (Dense)        (None, 64)                8256
# _________________________________________________________________
# output (Dense)               (None, 10)                650
# =================================================================
# Total params: 1,746,506
# Trainable params: 1,746,506
# Non-trainable params: 0
# _________________________________________________________________
# Experiment with LR = 0.01, OPT=[<class 'keras.optimizers.SGD'>, <class 'keras.optimizers.RMSprop'>, <class 'keras.optimizers.Adagrad'>, <class 'keras.optimizers.Adam'>]
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# hidden_layer4 (Dense)        (None, 64)                8256
# _________________________________________________________________
# output (Dense)               (None, 10)                650
# =================================================================
# Total params: 1,746,506
# Trainable params: 1,746,506
# Non-trainable params: 0
# _________________________________________________________________
# Experiment with LR = 0.01, OPT=[<class 'keras.optimizers.SGD'>, <class 'keras.optimizers.RMSprop'>, <class 'keras.optimizers.Adagrad'>, <class 'keras.optimizers.Adam'>]
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# hidden_layer4 (Dense)        (None, 64)                8256
# _________________________________________________________________
# output (Dense)               (None, 10)                650
# =================================================================
# Total params: 1,746,506
# Trainable params: 1,746,506
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 2.6086 - accuracy: 0.2186 - val_loss: 1.9404 - val_accuracy: 0.2685
# Epoch 2/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.8651 - accuracy: 0.3166 - val_loss: 1.8412 - val_accuracy: 0.3239
# Epoch 3/50
# 50000/50000 [==============================] - 3s 52us/step - loss: 1.7973 - accuracy: 0.3486 - val_loss: 1.7958 - val_accuracy: 0.3579
# Epoch 4/50
# 50000/50000 [==============================] - 3s 52us/step - loss: 1.7438 - accuracy: 0.3705 - val_loss: 1.6865 - val_accuracy: 0.3888
# Epoch 5/50
# 50000/50000 [==============================] - 3s 52us/step - loss: 1.7096 - accuracy: 0.3799 - val_loss: 1.7208 - val_accuracy: 0.3776
# Epoch 6/50
# 50000/50000 [==============================] - 3s 53us/step - loss: 1.6694 - accuracy: 0.3977 - val_loss: 1.6961 - val_accuracy: 0.3887
# Epoch 7/50
# 50000/50000 [==============================] - 3s 52us/step - loss: 1.6515 - accuracy: 0.4034 - val_loss: 1.6369 - val_accuracy: 0.4133
# Epoch 8/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 1.6264 - accuracy: 0.4154 - val_loss: 1.5995 - val_accuracy: 0.4238
# Epoch 9/50
# 50000/50000 [==============================] - 3s 52us/step - loss: 1.6068 - accuracy: 0.4239 - val_loss: 1.5629 - val_accuracy: 0.4481
# Epoch 10/50
# 50000/50000 [==============================] - 3s 52us/step - loss: 1.5810 - accuracy: 0.4351 - val_loss: 1.6087 - val_accuracy: 0.4314
# Epoch 11/50
# 50000/50000 [==============================] - 3s 53us/step - loss: 1.5805 - accuracy: 0.4333 - val_loss: 1.5727 - val_accuracy: 0.4394
# Epoch 12/50
# 50000/50000 [==============================] - 3s 53us/step - loss: 1.5698 - accuracy: 0.4383 - val_loss: 1.5874 - val_accuracy: 0.4264
# Epoch 13/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.5509 - accuracy: 0.4443 - val_loss: 1.5763 - val_accuracy: 0.4367
# Epoch 14/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.5428 - accuracy: 0.4510 - val_loss: 1.5469 - val_accuracy: 0.4482
# Epoch 15/50
# 50000/50000 [==============================] - 3s 52us/step - loss: 1.5519 - accuracy: 0.4465 - val_loss: 1.5932 - val_accuracy: 0.4333
# Epoch 16/50
# 50000/50000 [==============================] - 3s 52us/step - loss: 1.5201 - accuracy: 0.4584 - val_loss: 1.5661 - val_accuracy: 0.4485
# Epoch 17/50
# 50000/50000 [==============================] - 3s 53us/step - loss: 1.5197 - accuracy: 0.4581 - val_loss: 1.5393 - val_accuracy: 0.4557
# Epoch 18/50
# 50000/50000 [==============================] - 3s 53us/step - loss: 1.5067 - accuracy: 0.4640 - val_loss: 1.5973 - val_accuracy: 0.4368
# Epoch 19/50
# 50000/50000 [==============================] - 3s 52us/step - loss: 1.4992 - accuracy: 0.4659 - val_loss: 1.5308 - val_accuracy: 0.4587
# Epoch 20/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.5045 - accuracy: 0.4639 - val_loss: 1.6094 - val_accuracy: 0.4479
# Epoch 21/50
# 50000/50000 [==============================] - 3s 52us/step - loss: 1.4935 - accuracy: 0.4669 - val_loss: 1.5522 - val_accuracy: 0.4512
# Epoch 22/50
# 50000/50000 [==============================] - 3s 52us/step - loss: 1.4940 - accuracy: 0.4668 - val_loss: 1.5407 - val_accuracy: 0.4569
# Epoch 23/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.4841 - accuracy: 0.4714 - val_loss: 1.5343 - val_accuracy: 0.4610
# Epoch 24/50
# 50000/50000 [==============================] - 3s 53us/step - loss: 1.4733 - accuracy: 0.4769 - val_loss: 1.5534 - val_accuracy: 0.4490
# Epoch 25/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 1.4827 - accuracy: 0.4727 - val_loss: 1.5423 - val_accuracy: 0.4527
# Epoch 26/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.4765 - accuracy: 0.4761 - val_loss: 1.5458 - val_accuracy: 0.4621
# Epoch 27/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 1.4671 - accuracy: 0.4783 - val_loss: 1.5222 - val_accuracy: 0.4579
# Epoch 28/50
# 50000/50000 [==============================] - 3s 57us/step - loss: 1.4611 - accuracy: 0.4815 - val_loss: 1.5515 - val_accuracy: 0.4552
# Epoch 29/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 1.4579 - accuracy: 0.4826 - val_loss: 1.5618 - val_accuracy: 0.4481
# Epoch 30/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 1.4706 - accuracy: 0.4778 - val_loss: 1.5271 - val_accuracy: 0.4588
# Epoch 31/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.4502 - accuracy: 0.4842 - val_loss: 1.5277 - val_accuracy: 0.4571
# Epoch 32/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 1.4484 - accuracy: 0.4856 - val_loss: 1.5224 - val_accuracy: 0.4570
# Epoch 33/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.4542 - accuracy: 0.4830 - val_loss: 1.5314 - val_accuracy: 0.4619
# Epoch 34/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 1.4573 - accuracy: 0.4831 - val_loss: 1.5275 - val_accuracy: 0.4575
# Epoch 35/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 1.4427 - accuracy: 0.4890 - val_loss: 1.5693 - val_accuracy: 0.4499
# Epoch 36/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.4393 - accuracy: 0.4876 - val_loss: 1.5523 - val_accuracy: 0.4570
# Epoch 37/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 1.4342 - accuracy: 0.4921 - val_loss: 1.5191 - val_accuracy: 0.4634
# Epoch 38/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.4374 - accuracy: 0.4901 - val_loss: 1.5569 - val_accuracy: 0.4601
# Epoch 39/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 1.4388 - accuracy: 0.4903 - val_loss: 1.5204 - val_accuracy: 0.4602
# Epoch 40/50
# 50000/50000 [==============================] - 3s 52us/step - loss: 1.4286 - accuracy: 0.4943 - val_loss: 1.5640 - val_accuracy: 0.4596
# Epoch 41/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 1.4317 - accuracy: 0.4933 - val_loss: 1.5608 - val_accuracy: 0.4525
# Epoch 42/50
# 50000/50000 [==============================] - 3s 52us/step - loss: 1.4334 - accuracy: 0.4943 - val_loss: 1.5419 - val_accuracy: 0.4625
# Epoch 43/50
# 50000/50000 [==============================] - 3s 52us/step - loss: 1.4290 - accuracy: 0.4938 - val_loss: 1.5413 - val_accuracy: 0.4566
# Epoch 44/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 1.4180 - accuracy: 0.4973 - val_loss: 1.5624 - val_accuracy: 0.4565
# Epoch 45/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.4316 - accuracy: 0.4928 - val_loss: 1.5142 - val_accuracy: 0.4680
# Epoch 46/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.4135 - accuracy: 0.4984 - val_loss: 1.5209 - val_accuracy: 0.4648
# Epoch 47/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 1.4259 - accuracy: 0.4970 - val_loss: 1.5300 - val_accuracy: 0.4686
# Epoch 48/50
# 50000/50000 [==============================] - 3s 52us/step - loss: 1.4070 - accuracy: 0.4983 - val_loss: 1.5264 - val_accuracy: 0.4651
# Epoch 49/50
# 50000/50000 [==============================] - 3s 53us/step - loss: 1.4236 - accuracy: 0.4967 - val_loss: 1.4892 - val_accuracy: 0.4774
# Epoch 50/50
# 50000/50000 [==============================] - 3s 52us/step - loss: 1.4017 - accuracy: 0.5030 - val_loss: 1.5397 - val_accuracy: 0.4620
# Experiment with LR = 0.1, OPT=[<class 'keras.optimizers.SGD'>, <class 'keras.optimizers.RMSprop'>, <class 'keras.optimizers.Adagrad'>, <class 'keras.optimizers.Adam'>]
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# hidden_layer4 (Dense)        (None, 64)                8256
# _________________________________________________________________
# output (Dense)               (None, 10)                650
# =================================================================
# Total params: 1,746,506
# Trainable params: 1,746,506
# Non-trainable params: 0
# _________________________________________________________________
# Experiment with LR = 0.1, OPT=[<class 'keras.optimizers.SGD'>, <class 'keras.optimizers.RMSprop'>, <class 'keras.optimizers.Adagrad'>, <class 'keras.optimizers.Adam'>]
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# hidden_layer4 (Dense)        (None, 64)                8256
# _________________________________________________________________
# output (Dense)               (None, 10)                650
# =================================================================
# Total params: 1,746,506
# Trainable params: 1,746,506
# Non-trainable params: 0
# _________________________________________________________________
# Experiment with LR = 0.1, OPT=[<class 'keras.optimizers.SGD'>, <class 'keras.optimizers.RMSprop'>, <class 'keras.optimizers.Adagrad'>, <class 'keras.optimizers.Adam'>]
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# hidden_layer4 (Dense)        (None, 64)                8256
# _________________________________________________________________
# output (Dense)               (None, 10)                650
# =================================================================
# Total params: 1,746,506
# Trainable params: 1,746,506
# Non-trainable params: 0
# _________________________________________________________________
# Experiment with LR = 0.1, OPT=[<class 'keras.optimizers.SGD'>, <class 'keras.optimizers.RMSprop'>, <class 'keras.optimizers.Adagrad'>, <class 'keras.optimizers.Adam'>]
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# hidden_layer4 (Dense)        (None, 64)                8256
# _________________________________________________________________
# output (Dense)               (None, 10)                650
# =================================================================
# Total params: 1,746,506
# Trainable params: 1,746,506
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 579.3508 - accuracy: 0.1000 - val_loss: 2.3035 - val_accuracy: 0.1000
# Epoch 2/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 2.3040 - accuracy: 0.1004 - val_loss: 2.3036 - val_accuracy: 0.1000
# Epoch 3/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 2.3043 - accuracy: 0.0995 - val_loss: 2.3038 - val_accuracy: 0.1000
# Epoch 4/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 2.3054 - accuracy: 0.1010 - val_loss: 2.3094 - val_accuracy: 0.1000
# Epoch 5/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 2.3050 - accuracy: 0.0995 - val_loss: 2.3043 - val_accuracy: 0.1000
# Epoch 6/50
# 50000/50000 [==============================] - 3s 53us/step - loss: 2.3055 - accuracy: 0.0998 - val_loss: 2.3060 - val_accuracy: 0.1000
# Epoch 7/50
# 50000/50000 [==============================] - 3s 53us/step - loss: 2.3056 - accuracy: 0.0994 - val_loss: 2.3046 - val_accuracy: 0.1000
# Epoch 8/50
# 50000/50000 [==============================] - 3s 52us/step - loss: 2.3057 - accuracy: 0.0994 - val_loss: 2.3062 - val_accuracy: 0.1000
# Epoch 9/50
# 50000/50000 [==============================] - 3s 52us/step - loss: 2.3060 - accuracy: 0.1016 - val_loss: 2.3065 - val_accuracy: 0.1000
# Epoch 10/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 2.3063 - accuracy: 0.1006 - val_loss: 2.3083 - val_accuracy: 0.1000
# Epoch 11/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 2.3060 - accuracy: 0.0989 - val_loss: 2.3048 - val_accuracy: 0.1000
# Epoch 12/50
# 50000/50000 [==============================] - 3s 53us/step - loss: 2.3064 - accuracy: 0.0994 - val_loss: 2.3073 - val_accuracy: 0.1000
# Epoch 13/50
# 50000/50000 [==============================] - 3s 52us/step - loss: 2.3063 - accuracy: 0.0995 - val_loss: 2.3102 - val_accuracy: 0.1000
# Epoch 14/50
# 50000/50000 [==============================] - 3s 52us/step - loss: 2.3068 - accuracy: 0.0995 - val_loss: 2.3085 - val_accuracy: 0.1000
# Epoch 15/50
# 50000/50000 [==============================] - 3s 52us/step - loss: 2.3066 - accuracy: 0.0972 - val_loss: 2.3078 - val_accuracy: 0.1000
# Epoch 16/50
# 50000/50000 [==============================] - 3s 53us/step - loss: 2.3069 - accuracy: 0.1000 - val_loss: 2.3064 - val_accuracy: 0.1000
# Epoch 17/50
# 50000/50000 [==============================] - 3s 53us/step - loss: 2.3067 - accuracy: 0.1001 - val_loss: 2.3046 - val_accuracy: 0.1000
# Epoch 18/50
# 50000/50000 [==============================] - 3s 52us/step - loss: 2.3060 - accuracy: 0.0995 - val_loss: 2.3059 - val_accuracy: 0.1000
# Epoch 19/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 2.3072 - accuracy: 0.0990 - val_loss: 2.3054 - val_accuracy: 0.1000
# Epoch 20/50
# 50000/50000 [==============================] - 3s 57us/step - loss: 2.3076 - accuracy: 0.0989 - val_loss: 2.3058 - val_accuracy: 0.1000
# Epoch 21/50
# 50000/50000 [==============================] - 3s 53us/step - loss: 2.3067 - accuracy: 0.0995 - val_loss: 2.3063 - val_accuracy: 0.1000
# Epoch 22/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 2.3069 - accuracy: 0.0984 - val_loss: 2.3055 - val_accuracy: 0.1000
# Epoch 23/50
# 50000/50000 [==============================] - 3s 52us/step - loss: 2.3070 - accuracy: 0.0985 - val_loss: 2.3097 - val_accuracy: 0.1000
# Epoch 24/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 2.3066 - accuracy: 0.0999 - val_loss: 2.3043 - val_accuracy: 0.1000
# Epoch 25/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 2.3071 - accuracy: 0.0983 - val_loss: 2.3123 - val_accuracy: 0.1000
# Epoch 26/50
# 50000/50000 [==============================] - 3s 52us/step - loss: 2.3073 - accuracy: 0.0976 - val_loss: 2.3053 - val_accuracy: 0.1000
# Epoch 27/50
# 50000/50000 [==============================] - 3s 53us/step - loss: 2.3069 - accuracy: 0.1009 - val_loss: 2.3067 - val_accuracy: 0.1000
# Epoch 28/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 2.3075 - accuracy: 0.0991 - val_loss: 2.3058 - val_accuracy: 0.1000
# Epoch 29/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 2.3071 - accuracy: 0.1001 - val_loss: 2.3047 - val_accuracy: 0.1000
# Epoch 30/50
# 50000/50000 [==============================] - 3s 52us/step - loss: 2.3066 - accuracy: 0.1009 - val_loss: 2.3050 - val_accuracy: 0.1000
# Epoch 31/50
# 50000/50000 [==============================] - 3s 53us/step - loss: 2.3078 - accuracy: 0.0990 - val_loss: 2.3106 - val_accuracy: 0.1000
# Epoch 32/50
# 50000/50000 [==============================] - 3s 52us/step - loss: 2.3074 - accuracy: 0.0990 - val_loss: 2.3041 - val_accuracy: 0.1000
# Epoch 33/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 2.3062 - accuracy: 0.1012 - val_loss: 2.3062 - val_accuracy: 0.1000
# Epoch 34/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 2.3072 - accuracy: 0.1000 - val_loss: 2.3057 - val_accuracy: 0.1000
# Epoch 35/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 2.3070 - accuracy: 0.1010 - val_loss: 2.3061 - val_accuracy: 0.1000
# Epoch 36/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 2.3068 - accuracy: 0.0990 - val_loss: 2.3087 - val_accuracy: 0.1000
# Epoch 37/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 2.3076 - accuracy: 0.1005 - val_loss: 2.3058 - val_accuracy: 0.1000
# Epoch 38/50
# 50000/50000 [==============================] - 3s 52us/step - loss: 2.3065 - accuracy: 0.0994 - val_loss: 2.3044 - val_accuracy: 0.1000
# Epoch 39/50
# 50000/50000 [==============================] - 3s 52us/step - loss: 2.3074 - accuracy: 0.1007 - val_loss: 2.3056 - val_accuracy: 0.1000
# Epoch 40/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 2.3074 - accuracy: 0.0984 - val_loss: 2.3109 - val_accuracy: 0.1000
# Epoch 41/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 2.3067 - accuracy: 0.0996 - val_loss: 2.3049 - val_accuracy: 0.1000
# Epoch 42/50
# 50000/50000 [==============================] - 3s 52us/step - loss: 2.3068 - accuracy: 0.1009 - val_loss: 2.3121 - val_accuracy: 0.1000
# Epoch 43/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 2.3076 - accuracy: 0.0976 - val_loss: 2.3039 - val_accuracy: 0.1000
# Epoch 44/50
# 50000/50000 [==============================] - 3s 60us/step - loss: 2.3073 - accuracy: 0.0984 - val_loss: 2.3092 - val_accuracy: 0.1000
# Epoch 45/50
# 50000/50000 [==============================] - 3s 52us/step - loss: 2.3069 - accuracy: 0.1002 - val_loss: 2.3108 - val_accuracy: 0.1000
# Epoch 46/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 2.3072 - accuracy: 0.0984 - val_loss: 2.3045 - val_accuracy: 0.1000
# Epoch 47/50
# 50000/50000 [==============================] - 3s 52us/step - loss: 2.3072 - accuracy: 0.0991 - val_loss: 2.3069 - val_accuracy: 0.1000
# Epoch 48/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 2.3069 - accuracy: 0.0980 - val_loss: 2.3085 - val_accuracy: 0.1000
# Epoch 49/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 2.3072 - accuracy: 0.0988 - val_loss: 2.3060 - val_accuracy: 0.1000
# Epoch 50/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 2.3064 - accuracy: 0.0994 - val_loss: 2.3127 - val_accuracy: 0.1000
# Experiment with LR = 1, OPT=[<class 'keras.optimizers.SGD'>, <class 'keras.optimizers.RMSprop'>, <class 'keras.optimizers.Adagrad'>, <class 'keras.optimizers.Adam'>]
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# hidden_layer4 (Dense)        (None, 64)                8256
# _________________________________________________________________
# output (Dense)               (None, 10)                650
# =================================================================
# Total params: 1,746,506
# Trainable params: 1,746,506
# Non-trainable params: 0
# _________________________________________________________________
# Experiment with LR = 1, OPT=[<class 'keras.optimizers.SGD'>, <class 'keras.optimizers.RMSprop'>, <class 'keras.optimizers.Adagrad'>, <class 'keras.optimizers.Adam'>]
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# hidden_layer4 (Dense)        (None, 64)                8256
# _________________________________________________________________
# output (Dense)               (None, 10)                650
# =================================================================
# Total params: 1,746,506
# Trainable params: 1,746,506
# Non-trainable params: 0
# _________________________________________________________________
# Experiment with LR = 1, OPT=[<class 'keras.optimizers.SGD'>, <class 'keras.optimizers.RMSprop'>, <class 'keras.optimizers.Adagrad'>, <class 'keras.optimizers.Adam'>]
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# hidden_layer4 (Dense)        (None, 64)                8256
# _________________________________________________________________
# output (Dense)               (None, 10)                650
# =================================================================
# Total params: 1,746,506
# Trainable params: 1,746,506
# Non-trainable params: 0
# _________________________________________________________________
# Experiment with LR = 1, OPT=[<class 'keras.optimizers.SGD'>, <class 'keras.optimizers.RMSprop'>, <class 'keras.optimizers.Adagrad'>, <class 'keras.optimizers.Adam'>]
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# hidden_layer4 (Dense)        (None, 64)                8256
# _________________________________________________________________
# output (Dense)               (None, 10)                650
# =================================================================
# Total params: 1,746,506
# Trainable params: 1,746,506
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 3s 60us/step - loss: 29149547.3532 - accuracy: 0.0997 - val_loss: 2.3123 - val_accuracy: 0.1000
# Epoch 2/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 2.3130 - accuracy: 0.1005 - val_loss: 2.3233 - val_accuracy: 0.1000
# Epoch 3/50
# 50000/50000 [==============================] - 3s 51us/step - loss: 2.3182 - accuracy: 0.0975 - val_loss: 2.3142 - val_accuracy: 0.1000
# Epoch 4/50
# 50000/50000 [==============================] - 3s 52us/step - loss: 2.3206 - accuracy: 0.0984 - val_loss: 2.3322 - val_accuracy: 0.1000
# Epoch 5/50
# 50000/50000 [==============================] - 3s 51us/step - loss: 2.3208 - accuracy: 0.0987 - val_loss: 2.3217 - val_accuracy: 0.1000
# Epoch 6/50
# 50000/50000 [==============================] - 3s 52us/step - loss: 2.3247 - accuracy: 0.1005 - val_loss: 2.3221 - val_accuracy: 0.1000
# Epoch 7/50
# 50000/50000 [==============================] - 3s 50us/step - loss: 2.3269 - accuracy: 0.1010 - val_loss: 2.3470 - val_accuracy: 0.1000
# Epoch 8/50
# 50000/50000 [==============================] - 3s 52us/step - loss: 2.3285 - accuracy: 0.1004 - val_loss: 2.3170 - val_accuracy: 0.1000
# Epoch 9/50
# 50000/50000 [==============================] - 3s 52us/step - loss: 2.3262 - accuracy: 0.0996 - val_loss: 2.3358 - val_accuracy: 0.1000
# Epoch 10/50
# 50000/50000 [==============================] - 3s 52us/step - loss: 2.3307 - accuracy: 0.0997 - val_loss: 2.3483 - val_accuracy: 0.1000
# Epoch 11/50
# 50000/50000 [==============================] - 3s 51us/step - loss: 2.3299 - accuracy: 0.0996 - val_loss: 2.3335 - val_accuracy: 0.1000
# Epoch 12/50
# 50000/50000 [==============================] - 3s 51us/step - loss: 2.3333 - accuracy: 0.0995 - val_loss: 2.3525 - val_accuracy: 0.1000
# Epoch 13/50
# 50000/50000 [==============================] - 3s 50us/step - loss: 2.3339 - accuracy: 0.0971 - val_loss: 2.3324 - val_accuracy: 0.1000
# Epoch 14/50
# 50000/50000 [==============================] - 3s 51us/step - loss: 2.3310 - accuracy: 0.0998 - val_loss: 2.3377 - val_accuracy: 0.1000
# Epoch 15/50
# 50000/50000 [==============================] - 3s 52us/step - loss: 2.3306 - accuracy: 0.1011 - val_loss: 2.3186 - val_accuracy: 0.1000
# Epoch 16/50
# 50000/50000 [==============================] - 3s 50us/step - loss: 2.3322 - accuracy: 0.1011 - val_loss: 2.3508 - val_accuracy: 0.1000
# Epoch 17/50
# 50000/50000 [==============================] - 3s 51us/step - loss: 2.3290 - accuracy: 0.0994 - val_loss: 2.3412 - val_accuracy: 0.1000
# Epoch 18/50
# 50000/50000 [==============================] - 3s 53us/step - loss: 2.3345 - accuracy: 0.0983 - val_loss: 2.3228 - val_accuracy: 0.1000
# Epoch 19/50
# 50000/50000 [==============================] - 3s 53us/step - loss: 2.3318 - accuracy: 0.0992 - val_loss: 2.3380 - val_accuracy: 0.1000
# Epoch 20/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 2.3312 - accuracy: 0.1004 - val_loss: 2.3479 - val_accuracy: 0.1000
# Epoch 21/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 2.3331 - accuracy: 0.0991 - val_loss: 2.3322 - val_accuracy: 0.1000
# Epoch 22/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 2.3317 - accuracy: 0.1035 - val_loss: 2.3338 - val_accuracy: 0.1000
# Epoch 23/50
# 50000/50000 [==============================] - 3s 55us/step - loss: 2.3330 - accuracy: 0.1007 - val_loss: 2.3443 - val_accuracy: 0.1000
# Epoch 24/50
# 50000/50000 [==============================] - 3s 57us/step - loss: 2.3321 - accuracy: 0.1016 - val_loss: 2.3224 - val_accuracy: 0.1000
# Epoch 25/50
# 50000/50000 [==============================] - 3s 64us/step - loss: 2.3338 - accuracy: 0.0995 - val_loss: 2.3319 - val_accuracy: 0.1000
# Epoch 26/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 2.3296 - accuracy: 0.0995 - val_loss: 2.3572 - val_accuracy: 0.1000
# Epoch 27/50
# 50000/50000 [==============================] - 3s 60us/step - loss: 2.3306 - accuracy: 0.1017 - val_loss: 2.3252 - val_accuracy: 0.1000
# Epoch 28/50
# 50000/50000 [==============================] - 3s 64us/step - loss: 2.3342 - accuracy: 0.1002 - val_loss: 2.3330 - val_accuracy: 0.1000
# Epoch 29/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 2.3327 - accuracy: 0.0985 - val_loss: 2.3225 - val_accuracy: 0.1000
# Epoch 30/50
# 50000/50000 [==============================] - 3s 60us/step - loss: 2.3377 - accuracy: 0.1027 - val_loss: 2.3238 - val_accuracy: 0.1000
# Epoch 31/50
# 50000/50000 [==============================] - 3s 66us/step - loss: 2.3349 - accuracy: 0.1003 - val_loss: 2.3409 - val_accuracy: 0.1000
# Epoch 32/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 2.3310 - accuracy: 0.1011 - val_loss: 2.3378 - val_accuracy: 0.1000
# Epoch 33/50
# 50000/50000 [==============================] - 3s 52us/step - loss: 2.3328 - accuracy: 0.0992 - val_loss: 2.3174 - val_accuracy: 0.1000
# Epoch 34/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 2.3292 - accuracy: 0.0985 - val_loss: 2.3247 - val_accuracy: 0.1000
# Epoch 35/50
# 50000/50000 [==============================] - 3s 69us/step - loss: 2.3406 - accuracy: 0.0975 - val_loss: 2.3579 - val_accuracy: 0.1000
# Epoch 36/50
# 50000/50000 [==============================] - 3s 63us/step - loss: 2.3400 - accuracy: 0.0994 - val_loss: 2.3278 - val_accuracy: 0.1000
# Epoch 37/50
# 50000/50000 [==============================] - 3s 57us/step - loss: 2.3308 - accuracy: 0.0998 - val_loss: 2.3403 - val_accuracy: 0.1000
# Epoch 38/50
# 50000/50000 [==============================] - 3s 57us/step - loss: 2.3324 - accuracy: 0.0995 - val_loss: 2.3369 - val_accuracy: 0.1000
# Epoch 39/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 2.3344 - accuracy: 0.0987 - val_loss: 2.3252 - val_accuracy: 0.1000
# Epoch 40/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 2.3413 - accuracy: 0.1007 - val_loss: 2.3697 - val_accuracy: 0.1000
# Epoch 41/50
# 50000/50000 [==============================] - 3s 53us/step - loss: 2.3301 - accuracy: 0.0999 - val_loss: 2.3428 - val_accuracy: 0.1000
# Epoch 42/50
# 50000/50000 [==============================] - 3s 58us/step - loss: 2.3327 - accuracy: 0.1011 - val_loss: 2.3409 - val_accuracy: 0.1000
# Epoch 43/50
# 50000/50000 [==============================] - 3s 60us/step - loss: 2.3288 - accuracy: 0.1006 - val_loss: 2.3363 - val_accuracy: 0.1000
# Epoch 44/50
# 50000/50000 [==============================] - 3s 62us/step - loss: 2.3362 - accuracy: 0.0993 - val_loss: 2.3603 - val_accuracy: 0.1000
# Epoch 45/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 2.3376 - accuracy: 0.1016 - val_loss: 2.3359 - val_accuracy: 0.1000
# Epoch 46/50
# 50000/50000 [==============================] - 3s 56us/step - loss: 2.3315 - accuracy: 0.0996 - val_loss: 2.3305 - val_accuracy: 0.1000
# Epoch 47/50
# 50000/50000 [==============================] - 3s 54us/step - loss: 2.3376 - accuracy: 0.0989 - val_loss: 2.3508 - val_accuracy: 0.1000
# Epoch 48/50
# 50000/50000 [==============================] - 3s 59us/step - loss: 2.3403 - accuracy: 0.1014 - val_loss: 2.3632 - val_accuracy: 0.1000
# Epoch 49/50
# 50000/50000 [==============================] - 3s 53us/step - loss: 2.3306 - accuracy: 0.0982 - val_loss: 2.3431 - val_accuracy: 0.1000
# Epoch 50/50
# 50000/50000 [==============================] - 3s 50us/step - loss: 2.3319 - accuracy: 0.1007 - val_loss: 2.3360 - val_accuracy: 0.1000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

"""
將實驗結果繪出
"""
import matplotlib.pyplot as plt
# %matplotlib inline
"""Code Here
將結果繪出
"""
color_bar = ["r", "g", "b", "y", "m", "k"]

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-loss'])),results[cond]['train-loss'], '-', label=cond, color=color_bar[i])
plt.title("Loss")
plt.legend()
plt.show()

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['valid-loss'])),results[cond]['valid-loss'], '--', label=cond, color=color_bar[i])
plt.title("Loss")
plt.legend()
plt.show()

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-accuracy'])),results[cond]['train-accuracy'], '-', label=cond, color=color_bar[i])
plt.title("Accuracy")
plt.legend()
plt.show()

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['valid-accuracy'])),results[cond]['valid-accuracy'], '--', label=cond, color=color_bar[i])
plt.title("Accuracy")
plt.legend()
plt.show()
